# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("./shika_check.log", delim_whitespace=True, names=["path", "sample_name", "nhits", "mean_score"])

# %%
df.sort_values(by='nhits', ascending=False)
# Out:
#                                                              path sample_name  \
# FOUND: /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
#        /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
#        /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
#        /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
#        /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
#        /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
#        /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
#        /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
#        /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
#        /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
#        /isilon/users/target/target/AutoUsers/200715/ab...  WTPhC1       >=10:
# ...
